# %%
import pandas as pd
import numpy as np

from env import get_db_url

url = get_db_url('employees')

np.random.seed(123)

# %%
# Create list of values for names column.

students = [
    'Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas', 'Marie',
    'Albert', 'Richard', 'Isaac', 'Alan'
]

# Randomly generate arrays of scores for each student for each subject.
# Note that all the values need to have the same length here.

math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

# %%
# Construct the DataFrame using the above lists and arrays.

df = pd.DataFrame({
    'name': students,
    'math': math_grades,
    'english': english_grades,
    'reading': reading_grades,
    'classroom': np.random.choice(['A', 'B'], len(students))
})

# %%
pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
pd.DataFrame([[1, 2, 3], [4, 5, 6]])
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %%
array = np.array([[1, 2, 3], [4, 5, 6]])

pd.DataFrame(array, columns=['a', 'b', 'c'])
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6

# %%
from pydataset import data

# %%
# data(df_string_name, show_doc=True)

# %%
from env import get_db_url

url = get_db_url('employees')

# %%
pd.read_sql('SELECT * FROM employees LIMIT 5 OFFSET 50', url)
# Out:
#    emp_no  birth_date first_name  last_name gender   hire_date
# 0   10051  1953-07-28   Hidefumi      Caine      M  1992-10-15
# 1   10052  1961-02-26     Heping     Nitsch      M  1988-05-21
# 2   10053  1954-09-13     Sanjiv   Zschoche      F  1986-02-04
# 3   10054  1957-04-04     Mayumi  Schueller      M  1995-03-13
# 4   10055  1956-06-06     Georgy     Dredge      M  1992-04-27

# %%
sql = '''
SELECT
    emp_no,
    first_name,
    last_name
FROM employees
WHERE gender = 'F'
LIMIT 100
'''

employees = pd.read_sql(sql, url)
employees.head()
# Out:
#    emp_no first_name  last_name
# 0   10002    Bezalel     Simmel
# 1   10006     Anneke    Preusig
# 2   10007    Tzvetan  Zielinski
# 3   10009     Sumant       Peac
# 4   10010  Duangkaew   Piveteau

# %% [markdown]
# ## Exercises I
#
# Run python -m pip install pymysql from your terminal to install pymysql.
#
# Create a notebook or python script named advanced_dataframes to do your work in for these exercises.

# %% [markdown]
# 1. Run python -m pip install pymysql from your terminal to install the mysql client (any folder is fine)

# %% [markdown]
# 2. cd into your exercises folder for this module and run echo env.py >> .gitignore

# %% [markdown]
# 3. Create a function named get_db_url. It should accept a username, hostname, password, and database name and return a url connection string formatted like in the example at the start of this lesson.

# %% [markdown]
# 4. Use your function to obtain a connection to the employees database.

# %%
import pandas as pd
import numpy as np

from env import get_db_url

url = get_db_url('employees')

# %% [markdown]
# 5. Once you have successfully run a query:

# %%
print(pd.read_sql('SELECT * FROM employees LIMIT 5 OFFSET 50', url))
# Out:
#    emp_no  birth_date first_name  last_name gender   hire_date
# 0   10051  1953-07-28   Hidefumi      Caine      M  1992-10-15
# 1   10052  1961-02-26     Heping     Nitsch      M  1988-05-21
# 2   10053  1954-09-13     Sanjiv   Zschoche      F  1986-02-04
# 3   10054  1957-04-04     Mayumi  Schueller      M  1995-03-13
# 4   10055  1956-06-06     Georgy     Dredge      M  1992-04-27

# %% [markdown]
# a. Intentionally make a typo in the database url. What kind of error message do you see?

# %%
url = get_db_url('mployees')

### pd.read_sql('SELECT * FROM employees LIMIT 5 OFFSET 50', url)

# Got these error messages "OperationalError                          Traceback (most recent call last)"
# "OperationalError: (1044, "Access denied for user 'jemison_1749'@'%' to database 'mployees'")"
# "OperationalError: (pymysql.err.OperationalError) (1044, "Access denied for user 'jemison_1749'@'%' to database 'mployees'")
# (Background on this error at: https://sqlalche.me/e/14/e3q8)"

# %% [markdown]
# b. Intentionally make an error in your SQL query. What does the error message look like?

# %%
url = get_db_url('employees')

### pd.read_sql('SELECT ** FROM employees LIMIT 5 OFFSET 50', url)

# I get this error ProgrammingError: (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; 
# check the manual that corresponds to your MySQL server version for the right syntax to use near '* FROM 
# employees LIMIT 5 OFFSET 50' at line 1")

# %% [markdown]
# 6. Read the employees and titles tables into two separate DataFrames.

# %%
url = get_db_url('employees')

emp_df = pd.read_sql('SELECT * FROM employees LIMIT 5 OFFSET 50', url)
print(emp_df)

titles_df = pd.read_sql('SELECT * FROM titles LIMIT 5 OFFSET 50', url)
titles_df
# Out:
#    emp_no  birth_date first_name  last_name gender   hire_date
# 0   10051  1953-07-28   Hidefumi      Caine      M  1992-10-15
# 1   10052  1961-02-26     Heping     Nitsch      M  1988-05-21
# 2   10053  1954-09-13     Sanjiv   Zschoche      F  1986-02-04
# 3   10054  1957-04-04     Mayumi  Schueller      M  1995-03-13
# 4   10055  1956-06-06     Georgy     Dredge      M  1992-04-27
#    emp_no            title   from_date     to_date
# 0   10036     Senior Staff  1992-04-28  9999-01-01
# 1   10037         Engineer  1990-12-05  1995-12-05
# 2   10037  Senior Engineer  1995-12-05  9999-01-01
# 3   10038     Senior Staff  1996-09-20  9999-01-01
# 4   10038            Staff  1989-09-20  1996-09-20

# %% [markdown]
# 7. How many rows and columns do you have in each DataFrame? Is that what you expected?

# %%
url = get_db_url("employees")
sql = """ SELECT * FROM employees"""
titles = pd.read_sql(sql, url)
titles.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %% [markdown]
# 8. Display the summary statistics for each DataFrame.

# %%
employees.describe()
# Out:
#              emp_no
# count    100.000000
# mean   10132.200000
# std       74.008463
# min    10002.000000
# 25%    10074.750000
# 50%    10126.000000
# 75%    10198.000000
# max    10253.000000

# %%
sql = """ SELECT * FROM titles"""
employees = pd.read_sql(sql, url)

titles.describe(include='all')
# shows the min and max in the output
# Out:
#                emp_no  birth_date first_name last_name  gender   hire_date
# count   300024.000000      300024     300024    300024  300024      300024
# unique            NaN        4750       1275      1637       2        5434
# top               NaN  1952-03-08     Shahab      Baba       M  1985-06-20
# freq              NaN          95        295       226  179973         132
# mean    253321.763392         NaN        NaN       NaN     NaN         NaN
# std     161828.235540         NaN        NaN       NaN     NaN         NaN
# min      10001.000000         NaN        NaN       NaN     NaN         NaN
# 25%      85006.750000         NaN        NaN       NaN     NaN         NaN
# 50%     249987.500000         NaN        NaN       NaN     NaN         NaN
# 75%     424993.250000         NaN        NaN       NaN     NaN         NaN
# max     499999.000000         NaN        NaN       NaN     NaN         NaN

# %% [markdown]
# 9. How many unique titles are in the titles DataFrame?

# %%
#Example of solving the problem only with SQl
sql = """
SELECT COUNT(DISTINCT title) from titles;"""
pd.read_sql(sql, url)
# Out:
#    COUNT(DISTINCT title)
# 0                      7

# %%
# pandas approach
# len(titles.title.unique())

# %% [markdown]
# 10. What is the oldest date in the to_date column?

# %%
pd.read_sql("SELECT MIN(to_date) FROM titles", url)
# Out:
#   MIN(to_date)
# 0   1985-03-01

# %%
# titles.to_date.min()

# %% [markdown]
# 11. What is the most recent date in the to_date column?

# %%
pd.read_sql("SELECT MAX(to_date) FROM titles", url)
# Out:
#   MAX(to_date)
# 0   9999-01-01

# %%
#pandas approach
titles.dtypes
# Out:
# emp_no         int64
# birth_date    object
# first_name    object
# last_name     object
# gender        object
# hire_date     object
# dtype: object

# %%
# pd.to_datetim(titles.to_date) this would work except for the 9999 year

# %% [markdown]
# # Exercises II

# %% [markdown]
# 1. Copy the users and roles DataFrames from the examples above.

# %%
# Create the users DataFrame.

users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users

# Create the roles DataFrame

roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %% [markdown]
# 2. What is the result of using a right join on the DataFrames?

# %%
users.merge(roles, how='right', on=None, left_on=None, right_on=None, left_index=False, right_index=False, indicator=False)
# It tacked on the role_id column to the roles dataframe and kept the original column values from the roles dataframe that had the same name as the users dataframe

# Rev 

users.merge(roles, left_on='role_id', right_on='id', how='right', indicator=True)
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0     1      admin        both
# 1   2.0    joe      2.0     2     author        both
# 2   3.0  sally      3.0     3   reviewer        both
# 3   4.0   adam      3.0     3   reviewer        both
# 4   NaN    NaN      NaN     4  commenter  right_only

# %%
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
pd.concat([users, roles], axis=0)
# Out:
#    id       name  role_id
# 0   1        bob      1.0
# 1   2        joe      2.0
# 2   3      sally      3.0
# 3   4       adam      3.0
# 4   5       jane      NaN
# 5   6       mike      NaN
# 0   1      admin      NaN
# 1   2     author      NaN
# 2   3   reviewer      NaN
# 3   4  commenter      NaN

# %% [markdown]
# 3. What is the result of using an outer join on the DataFrames?

# %%
users.merge(roles, how='outer', on=None, left_on=None, right_on=None, left_index=False, right_index=False, indicator=False)
# It essentially concatenated the two dataframes on top of each other keeping all of their original values or filling in NaN if there were none
# Out:
#    id       name  role_id
# 0   1        bob      1.0
# 1   2        joe      2.0
# 2   3      sally      3.0
# 3   4       adam      3.0
# 4   5       jane      NaN
# 5   6       mike      NaN
# 6   1      admin      NaN
# 7   2     author      NaN
# 8   3   reviewer      NaN
# 9   4  commenter      NaN

# %% [markdown]
# 4. What happens if you drop the foreign keys from the DataFrames and try to merge them?

# %%
key_free_users = users.drop(['id'], axis = 1)
key_free_users
# Out:
#     name  role_id
# 0    bob      1.0
# 1    joe      2.0
# 2  sally      3.0
# 3   adam      3.0
# 4   jane      NaN
# 5   mike      NaN

# %%
key_free_roles = roles.drop(['id'], axis = 1)
key_free_roles
# Out:
#         name
# 0      admin
# 1     author
# 2   reviewer
# 3  commenter

# %%
key_free_users.merge(key_free_roles, how='inner', on=None, left_on=None, right_on=None, left_index=False, right_index=False, indicator=False)
# It returned a dataframe without any values.  I think it combined them together essentially replacing the index and name columns and adding role_id
# Out:
# Empty DataFrame
# Columns: [name, role_id]
# Index: []

# %% [markdown]
# 5. Load the mpg dataset from PyDataset.

# %%
from pydataset import data

mpg = data('mpg') # load the dataset and store it in a variable
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %% [markdown]
# 6. Output and read the documentation for the mpg dataset.

# %%
data ('mpg', show_doc = True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %% [markdown]
# 7. How many rows and columns are in the dataset?

# %%
mpg.shape
# Out:
# (234, 11)

# %% [markdown]
# 8. Check out your column names and perform any cleanup you may want on them.

# %%
mpg.columns.tolist()

# Rev mpg.rename(columns = {'cty': "city", 'hwy': 'highway'})
mpg.columns = ['manufacturer', 'model', 'displacement', 'year', 'cylinders', 'transmission', 'drive', 'city', 'highway', 'fl', 'class']

# %% [markdown]
# 9. Display the summary statistics for the dataset.

# %%
mpg.describe()
# Out:
#        displacement         year   cylinders        city     highway
# count    234.000000   234.000000  234.000000  234.000000  234.000000
# mean       3.471795  2003.500000    5.888889   16.858974   23.440171
# std        1.291959     4.509646    1.611534    4.255946    5.954643
# min        1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%        2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%        3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%        4.600000  2008.000000    8.000000   19.000000   27.000000
# max        7.000000  2008.000000    8.000000   35.000000   44.000000

# %% [markdown]
# 10. How many different manufacturers are there?

# %%
mpg.manufacturer.nunique()

# Rev I can use the `.nunique()` function to count the unique values in the column.
# Out:
# 15

# %% [markdown]
# 11. How many different models are there?

# %%
mpg.model.nunique()
# Rev unique gives you the actual values of each unique variable while nuniqe gives you the count of how many unique values you have
# Out:
# 38

# %% [markdown]
# 12. Create a column named mileage_difference like you did in the DataFrames exercises; this column should contain the difference between highway and city mileage for each car.

# %%
mpg['mileage_difference'] = mpg.highway - mpg.city

mpg.head()
# Out:
#   manufacturer model  displacement  year  cylinders transmission drive  city  \
# 1         audi    a4           1.8  1999          4     auto(l5)     f    18
# 2         audi    a4           1.8  1999          4   manual(m5)     f    21
# 3         audi    a4           2.0  2008          4   manual(m6)     f    20
# 4         audi    a4           2.0  2008          4     auto(av)     f    21
# 5         audi    a4           2.8  1999          6     auto(l5)     f    16
#
#    highway fl    class  mileage_difference
# 1       29  p  compact                  11
# 2       29  p  compact                   8
# 3       31  p  compact                  11
# 4       30  p  compact                   9
# 5       26  p  compact                  10

# %% [markdown]
# 13. Create a column named average_mileage like you did in the DataFrames exercises; this is the mean of the city and highway mileage.

# %%
mpg['average_mileage'] = (mpg.city + mpg.highway)/2

# %% [markdown]
# 14. Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.

# %%
mpg.transmission.unique()
# Rev check the values in the `transmission` column to see what you're working with
# create a new column is_automatic

mpg['is_automatic'] = mpg.transmission.str.contains('auto')

mpg.head()
# Out:
#   manufacturer model  displacement  year  cylinders transmission drive  city  \
# 1         audi    a4           1.8  1999          4     auto(l5)     f    18
# 2         audi    a4           1.8  1999          4   manual(m5)     f    21
# 3         audi    a4           2.0  2008          4   manual(m6)     f    20
# 4         audi    a4           2.0  2008          4     auto(av)     f    21
# 5         audi    a4           2.8  1999          6     auto(l5)     f    16
#
#    highway fl    class  mileage_difference  average_mileage  is_automatic
# 1       29  p  compact                  11             23.5          True
# 2       29  p  compact                   8             25.0         False
# 3       31  p  compact                  11             25.5         False
# 4       30  p  compact                   9             25.5          True
# 5       26  p  compact                  10             21.0          True

# %% [markdown]
# 15. Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?
#
# - we can use the `.grouby()` method on a column and perform an aggregation on another, or other, column(s).
#
# - Look at the highest average for average_mileage by manfacturer as a target.

# %%
mpg.groupby('manufacturer').average_mileage.mean().sort_values(ascending = False)
# mpg.groupby('manufacturer').average_mileage.mean()
# Out:
# manufacturer
# honda         28.500000
# volkswagen    25.074074
# hyundai       22.750000
# subaru        22.428571
# audi          22.027778
# toyota        21.720588
# pontiac       21.700000
# nissan        21.346154
# chevrolet     18.447368
# ford          16.680000
# mercury       15.625000
# jeep          15.562500
# dodge         15.540541
# lincoln       14.166667
# land rover    14.000000
# Name: average_mileage, dtype: float64

# %% [markdown]
# 16. Do automatic or manual cars have better miles per gallon?
# - Rev ceate a column, tansmission_category, that contains auto if a care has any type of automatic transmission

# %%
mpg['transmission_category']= np.where(mpg.transmission.str.contains('augto'), 'automatic', 'manual')
mpg.head()
# Out:
#   manufacturer model  displacement  year  cylinders transmission drive  city  \
# 1         audi    a4           1.8  1999          4     auto(l5)     f    18
# 2         audi    a4           1.8  1999          4   manual(m5)     f    21
# 3         audi    a4           2.0  2008          4   manual(m6)     f    20
# 4         audi    a4           2.0  2008          4     auto(av)     f    21
# 5         audi    a4           2.8  1999          6     auto(l5)     f    16
#
#    highway fl    class  mileage_difference  average_mileage  is_automatic  \
# 1       29  p  compact                  11             23.5          True
# 2       29  p  compact                   8             25.0         False
# 3       31  p  compact                  11             25.5         False
# 4       30  p  compact                   9             25.5          True
# 5       26  p  compact                  10             21.0          True
#
#   transmission_category
# 1                manual
# ...

# %%
# Rev group by transmission category
mpg.groupby('transmission_category')[['average_mileage']].mean().round(1)
# Out:
#                        average_mileage
# transmission_category
# manual                            20.1

# %% [markdown]
# # Exercises III

# %% [markdown]
# 1. Use your get_db_url function to help you explore the data from the chipotle database.

# %%
url = get_db_url('chipotle')

# %% [markdown]
# 2. What is the total price for each order?

# %%
pd.read_sql('SELECT * FROM orders', url)
chip = pd.read_sql('SELECT * FROM orders', url)
chip
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %%
chip.shape
# Out:
# (4622, 6)

# %%
type(chip)
# Out:
# pandas.core.frame.DataFrame

# %%
chip.describe
# Out:
# <bound method NDFrame.describe of         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %%
chip.item_price.sum()
# Out:
# '$2.39 $3.39 $3.39 $2.39 $16.98 $10.98 $1.69 $11.75 $9.25 $9.25 $4.45 $8.75 $8.75 $11.25 $4.45 $2.39 $8.49 $8.49 $2.18 $8.75 $4.45 $8.99 $3.39 $10.98 $3.39 $2.39 $8.49 $8.99 $1.09 $8.49 $2.39 $8.99 $1.69 $8.99 $1.09 $8.75 $8.75 $4.45 $2.95 $11.75 $2.15 $4.45 $11.25 $11.75 $8.75 $10.98 $8.99 $3.39 $8.99 $3.99 $8.99 $2.18 $10.98 $1.09 $8.99 $2.39 $9.25 $11.25 $11.75 $2.15 $4.45 $9.25 $11.25 $8.75 $8.99 $8.99 $3.39 $8.99 $10.98 $8.99 $1.69 $8.99 $3.99 $8.75 $4.45 $8.75 $8.75 $2.15 $8.75 $11.25 $2.15 $9.25 $8.75 $8.75 $9.25 $8.49 $8.99 $1.09 $9.25 $2.95 $11.75 $11.75 $9.25 $11.75 $4.45 $9.25 $4.45 $11.75 $8.75 $8.75 $4.45 $8.99 $8.99 $3.99 $8.49 $3.39 $8.99 $1.09 $9.25 $4.45 $8.75 $2.95 $4.45 $2.39 $8.49 $8.99 $8.49 $1.09 $8.99 $3.99 $8.75 $9.25 $4.45 $11.25 $4.45 $8.99 $1.09 $9.25 $2.95 $4.45 $11.75 $4.45 $8.49 $2.39 $10.98 $22.50 $11.75 $4.45 $11.25 $4.45 $11.25 $4.45 $11.25 $11.25 $11.75 $9.25 $4.45 $11.48 $17.98 $1.69 $17.50 $4.45 $8.49 $2.39 $17.50 $4.45 $4.45 $11.25 $11.75 $10.98 $
# ...

# %%
# chip['item_price'] = chip['item_price'].str.replace(r'$','', regex=True
prices = chip['item_price'].str.replace('$', '', regex=True).astype(float)

# float doesn't need to be in quotes???

pd.DataFrame(prices)
# Out:
#       item_price
# 0           2.39
# 1           3.39
# 2           3.39
# 3           2.39
# 4          16.98
# ...          ...
# 4617       11.75
# 4618       11.75
# 4619       11.25
# 4620        8.75
# 4621        8.75
#
# [4622 rows x 1 columns]

# %%
prices.sum()
# 34500.16 is the total price for each order
# Out:
# 34500.16

# %% [markdown]
# 3. What are the most popular 3 items?

# %%
pd.DataFrame(chip.groupby(["item_name"]).count())
# Out:
#                                         id  order_id  quantity  \
# item_name
# 6 Pack Soft Drink                       54        54        54
# Barbacoa Bowl                           66        66        66
# Barbacoa Burrito                        91        91        91
# Barbacoa Crispy Tacos                   11        11        11
# Barbacoa Salad Bowl                     10        10        10
# Barbacoa Soft Tacos                     25        25        25
# Bottled Water                          162       162       162
# Bowl                                     2         2         2
# Burrito                                  6         6         6
# Canned Soda                            104       104       104
# Canned Soft Drink                      301       301       301
# Carnitas Bowl                           68        68        68
# Carnitas Burrito                        59        59        59
# Carnitas Crispy Tacos                    7         7         7
# ...

# %%
top_3 = chip.pivot_table(columns=['item_name'], aggfunc='size')
print(type(top_3))
top_3 = pd.DataFrame(top_3)
print(type(top_3))
top_3
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
#                                          0
# item_name
# 6 Pack Soft Drink                       54
# Barbacoa Bowl                           66
# Barbacoa Burrito                        91
# Barbacoa Crispy Tacos                   11
# Barbacoa Salad Bowl                     10
# Barbacoa Soft Tacos                     25
# Bottled Water                          162
# Bowl                                     2
# Burrito                                  6
# Canned Soda                            104
# Canned Soft Drink                      301
# Carnitas Bowl                           68
# Carnitas Burrito                        59
# Carnitas Crispy Tacos                    7
# Carnitas Salad                           1
# Carnitas Salad Bowl                      6
# Carnitas Soft Tacos                     40
# Chicken Bowl                           726
# Chicken Burrito                        553
# ...

# %%
top_3.columns = ['popularity']
top_3
# Out:
#                                        popularity
# item_name
# 6 Pack Soft Drink                              54
# Barbacoa Bowl                                  66
# Barbacoa Burrito                               91
# Barbacoa Crispy Tacos                          11
# Barbacoa Salad Bowl                            10
# Barbacoa Soft Tacos                            25
# Bottled Water                                 162
# Bowl                                            2
# Burrito                                         6
# Canned Soda                                   104
# Canned Soft Drink                             301
# Carnitas Bowl                                  68
# Carnitas Burrito                               59
# Carnitas Crispy Tacos                           7
# Carnitas Salad                                  1
# Carnitas Salad Bowl                             6
# Carnitas Soft Tacos                            40
# Chicken Bowl                                  726
# ...

# %%
top_3.sort_values(by='popularity', ascending=False).head(3)
# Chicken Bowl, Chicken Burrito, and Chips and Guacamole are the 3 most popular items
# Out:
#                      popularity
# item_name
# Chicken Bowl                726
# Chicken Burrito             553
# Chips and Guacamole         479

# %% [markdown]
# 4. Which item has produced the most revenue?

# %%
prices = chip['item_price'].str.replace('$', '', regex=True).astype(float)

pd.DataFrame(prices)
# Out:
#       item_price
# 0           2.39
# 1           3.39
# 2           3.39
# 3           2.39
# 4          16.98
# ...          ...
# 4617       11.75
# 4618       11.75
# 4619       11.25
# 4620        8.75
# 4621        8.75
#
# [4622 rows x 1 columns]

# %%
chip['prices'] = prices
chip
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %%
most_revenue = pd.DataFrame(chip.groupby(["item_name"]).sum())
most_revenue
# Out:
#                                             id  order_id  quantity   prices
# item_name
# 6 Pack Soft Drink                       130372     52322        55   356.95
# Barbacoa Bowl                           134330     53972        66   672.36
# Barbacoa Burrito                        186070     74718        91   894.75
# Barbacoa Crispy Tacos                    13836      5613        12   120.21
# Barbacoa Salad Bowl                      24171      9708        10   106.40
# Barbacoa Soft Tacos                      46479     18725        25   250.46
# Bottled Water                           439516    175944       211   302.56
# Bowl                                      1120       472         4    29.60
# Burrito                                   3740      1550         6    44.40
# Canned Soda                             190019     76396       126   137.34
# Canned Soft Drink                       760291    304753       351   438.75
# ...

# %%
most_revenue.sort_values(by='prices', ascending=False).head(1)
# The Chicken Bowl produced the most revenue

# Rev orders.groupby(’item_name')[['item_price']].sum().sort_values(by = 'item_price', ascending = False).head(1)
# Out:
#                    id  order_id  quantity   prices
# item_name
# Chicken Bowl  1780635    713926       761  7342.73

# %% [markdown]
# 5. Join the employees and titles DataFrames together.

# %%
type(employees)
url = get_db_url('employees')

# %%
emp_df = pd.read_sql('SELECT * FROM employees', url)
print(emp_df)

titles_df = pd.read_sql('SELECT * FROM titles', url)
titles_df
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# ...

# %%
emp_df
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %%
emp_titles_df = emp_df.merge(titles_df, how='right', on=None, left_on=None, right_on=None, left_index=False, right_index=False, indicator=False)
# Joined the employees and titles DataFrames together.
emp_titles_df
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 443303  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443304  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443305  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443306  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443307  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title   from_date     to_date
# 0       Senior Engineer  1986-06-26  9999-01-01
# 1                 Staff  1996-08-03  9999-01-01
# ...

# %% [markdown]
# 6. For each title, find the hire date of the employee that was hired most recently with that title.

# %%
head_titles = emp_titles_df.groupby('title')[['hire_date']].max().reset_index()

# %%
emp_titles_df['from_date'] = pd.to_datetime(emp_titles_df['from_date'], format='%Y-%m-%d')
emp_titles_df
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 443303  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443304  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443305  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443306  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443307  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title  from_date     to_date
# 0       Senior Engineer 1986-06-26  9999-01-01
# 1                 Staff 1996-08-03  9999-01-01
# ...

# %%
from_date_emp_titles_df = pd.to_datetime(emp_titles_df['from_date'], infer_datetime_format=True)
from_date_emp_titles_df = pd.DataFrame(from_date_emp_titles_df)
from_date_emp_titles_df
# Out:
#         from_date
# 0      1986-06-26
# 1      1996-08-03
# 2      1995-12-03
# 3      1986-12-01
# 4      1995-12-01
# ...           ...
# 443303 1987-08-30
# 443304 1992-08-29
# 443305 1998-12-27
# 443306 1993-12-27
# 443307 1997-11-30
#
# [443308 rows x 1 columns]

# %%
emp_titles_df['date_type_from_dates'] = from_date_emp_titles_df
emp_titles_df
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 443303  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443304  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443305  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443306  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443307  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title  from_date     to_date date_type_from_dates
# 0       Senior Engineer 1986-06-26  9999-01-01           1986-06-26
# ...

# %%
recently_hired = pd.DataFrame(emp_titles_df.groupby(["title"]).max())

# %%
pd.merge(head_titles, emp_titles_df, left_on = ['title', 'hire_date'], right_on = ['title', 'hire_date'], how = 'left')
# Out:
#                 title   hire_date  emp_no  birth_date   first_name last_name  \
# 0  Assistant Engineer  1999-12-24  243702  1961-10-04     Munehiro      Luke
# 1            Engineer  2000-01-28  463807  1964-06-12       Bikash    Covnot
# 2             Manager  1992-02-05  110420  1963-07-27        Oscar  Ghazalie
# 3     Senior Engineer  2000-01-01  108201  1955-04-14  Mariangiola   Boreale
# 4        Senior Staff  2000-01-13  222965  1959-08-07      Volkmar     Perko
# 5               Staff  2000-01-12   47291  1960-09-09          Ulf    Flexer
# 6    Technique Leader  1999-12-31  294732  1960-11-07       Karlis    Orsini
#
#   gender  from_date     to_date date_type_from_dates
# 0      F 2000-01-07  9999-01-01           2000-01-07
# 1      M 2000-02-01  2000-05-19           2000-02-01
# 2      M 1996-08-30  9999-01-01           1996-08-30
# 3      M 2000-01-01  9999-01-01           2000-01-01
# 4      F 2000-01-29  9999-01-01           2000-01-29
# ...

# %% [markdown]
# 7. Write the code necessary to create a cross tabulation of the number of titles by department. (Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code to perform the manipulations.)

# %%
# Rev 
query = '''

SELECT emp_no, title, dept_name

FROM employees
JOIN titles USING(emp_no)
JOIN dept_emp USING(emp_no)
JOIN departments USING(dept_no)

where titles.to_date = "9999-01-01"
and dept_emp.to_date = "9999-01-01"'''
                   
url = get_db_url('employees')
xtab = pd.read_sql(query, url)

# %%
xtab.head
# Out:
# <bound method NDFrame.head of         emp_no            title        dept_name
# 0        10001  Senior Engineer      Development
# 1        10002            Staff            Sales
# 2        10003  Senior Engineer       Production
# 3        10004  Senior Engineer       Production
# 4        10005     Senior Staff  Human Resources
# ...        ...              ...              ...
# 240119  499995         Engineer       Production
# 240120  499996  Senior Engineer       Production
# 240121  499997  Senior Engineer      Development
# 240122  499998     Senior Staff          Finance
# 240123  499999         Engineer       Production
#
# [240124 rows x 3 columns]>

# %%
xtab.shape
# Out:
# (240124, 3)

# %%
# use pdf.crosstab to create cross tabulation
pd.crosstab(xtab.dept_name, xtab.title)
# Out:
# title               Assistant Engineer  Engineer  Manager  Senior Engineer  \
# dept_name
# Customer Service                    68       627        1             1790
# Development                       1652     14040        1            38816
# Finance                              0         0        1                0
# Human Resources                      0         0        1                0
# Marketing                            0         0        1                0
# Production                        1402     12081        1            33625
# Quality Management                 389      3405        1             9458
# Research                            77       830        1             2250
# Sales                                0         0        1                0
#
# title               Senior Staff  Staff  Technique Leader
# dept_name
# Customer Service           11268   3574               241
# Development                 1085    315              5477
# ...

# %%
xtab.groupby(['title', 'dept_name']).emp_no.count()
# Out:
# title               dept_name
# Assistant Engineer  Customer Service         68
#                     Development            1652
#                     Production             1402
#                     Quality Management      389
#                     Research                 77
# Engineer            Customer Service        627
#                     Development           14040
#                     Production            12081
#                     Quality Management     3405
#                     Research                830
# Manager             Customer Service          1
#                     Development               1
#                     Finance                   1
#                     Human Resources           1
#                     Marketing                 1
#                     Production                1
#                     Quality Management        1
#                     Research                  1
#                     Sales                     1
# ...
